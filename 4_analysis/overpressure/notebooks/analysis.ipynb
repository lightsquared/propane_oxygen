# %%
import pandas as pd
pd.options.display.html.table_schema = True

# %%
df = pd.read_csv('20140701_PropaneTank_Shot-1_PencilProbeData.csv')

# %%
df
# Out:
#        Time [s]   Trigger  X-Axis_PP-3 [psi]  X-Axis_PP-4 [psi]  \
# 0     -0.000684  0.057678           0.022888           0.004578
# 1     -0.000684  0.058594           0.001526          -0.004578
# 2     -0.000683  0.059509           0.007629          -0.025940
# 3     -0.000683  0.059814           0.001526          -0.012207
# 4     -0.000683  0.058289           0.006104          -0.001526
# 5     -0.000682  0.059509          -0.018311          -0.004578
# 6     -0.000682  0.059509          -0.009155          -0.006104
# 7     -0.000681  0.059814           0.004578          -0.004578
# 8     -0.000681  0.059509           0.012207          -0.013733
# 9     -0.000680  0.059509           0.015259           0.000000
# 10    -0.000679  0.060730          -0.025940          -0.003052
# 11    -0.000679  0.059814          -0.024414          -0.021362
# 12    -0.000679  0.057068          -0.013733          -0.004578
# 13    -0.000678  0.058289          -0.036621           0.009155
# ...
